# %%
# Load libraries
import requests
import json
import pandas as pd


url = "https://api.openf1.org/v1/drivers?"
Methods= ('drivers?')

response = requests.request("GET", url, data=payload)
data = response.text
parse_json= json.loads(data)
df = pd.DataFrame(parse_json)
df
# Out:
#       driver_number broadcast_name        full_name name_acronym  \
# 0                 1   M VERSTAPPEN   Max VERSTAPPEN          VER
# 1                 2     L SARGEANT   Logan SARGEANT          SAR
# 2                 4       L NORRIS     Lando NORRIS          NOR
# 3                10        P GASLY     Pierre GASLY          GAS
# 4                11        S PEREZ     Sergio PEREZ          PER
# ...             ...            ...              ...          ...
# 2481             38      O BEARMAN   Oliver BEARMAN          BEA
# 2482             44     L HAMILTON   Lewis HAMILTON          HAM
# 2483             63      G RUSSELL   George RUSSELL          RUS
# 2484             77       V BOTTAS  Valtteri BOTTAS          BOT
# 2485             81      O PIASTRI    Oscar PIASTRI          PIA
#
#             team_name                                        team_colour  \
# 0     Red Bull Racing                                             3671C6
# 1            Williams                                             37BEDD
# 2             McLaren                                             F58020
# 3              Alpine                                             2293D1
# 4     Red Bull Racing                                             3671C6
# ...               ...                                                ...
# 2481          Ferrari                                             e8002d
# 2482         Mercedes                                             27f4d2
# 2483         Mercedes                                             27f4d2
# 2484      Kick Sauber  5200000000000000190003903645130092385429788960...
# 2485          McLaren                                             ff8000
#
#      first_name   last_name  \
# 0           Max  Verstappen
# 1         Logan    Sargeant
# 2         Lando      Norris
# 3        Pierre       Gasly
# 4        Sergio       Perez
# ...         ...         ...
# 2481     Oliver     Bearman
# 2482      Lewis    Hamilton
# 2483     George     Russell
# 2484   Valtteri      Bottas
# 2485      Oscar     Piastri
#
#                                            headshot_url country_code  \
# 0     https://www.formula1.com/content/dam/fom-websi...          NED
# 1     https://www.formula1.com/content/dam/fom-websi...          USA
# 2     https://www.formula1.com/content/dam/fom-websi...          GBR
# 3     https://www.formula1.com/content/dam/fom-websi...          FRA
# 4     https://www.formula1.com/content/dam/fom-websi...          MEX
# ...                                                 ...          ...
# 2481                                               None          GBR
# 2482  https://media.formula1.com/d_driver_fallback_i...          GBR
# 2483  https://media.formula1.com/d_driver_fallback_i...          GBR
# 2484  https://media.formula1.com/d_driver_fallback_i...          FIN
# 2485  https://media.formula1.com/d_driver_fallback_i...          AUS
#
#       session_key  meeting_key
# 0            7763         1140
# 1            7763         1140
# 2            7763         1140
# 3            7763         1140
# 4            7763         1140
# ...           ...          ...
# 2481         9480         1230
# 2482         9480         1230
# 2483         9480         1230
# 2484         9480         1230
# 2485         9480         1230
#
# [2486 rows x 12 columns]

# %%
# Out:
#       driver_number broadcast_name        full_name name_acronym  \
# 0                 1   M VERSTAPPEN   Max VERSTAPPEN          VER
# 1                 2     L SARGEANT   Logan SARGEANT          SAR
# 2                 4       L NORRIS     Lando NORRIS          NOR
# 3                10        P GASLY     Pierre GASLY          GAS
# 4                11        S PEREZ     Sergio PEREZ          PER
# ...             ...            ...              ...          ...
# 2481             38      O BEARMAN   Oliver BEARMAN          BEA
# 2482             44     L HAMILTON   Lewis HAMILTON          HAM
# 2483             63      G RUSSELL   George RUSSELL          RUS
# 2484             77       V BOTTAS  Valtteri BOTTAS          BOT
# 2485             81      O PIASTRI    Oscar PIASTRI          PIA
#
#             team_name                                        team_colour  \
# 0     Red Bull Racing                                             3671C6
# 1            Williams                                             37BEDD
# 2             McLaren                                             F58020
# 3              Alpine                                             2293D1
# 4     Red Bull Racing                                             3671C6
# ...               ...                                                ...
# 2481          Ferrari                                             e8002d
# 2482         Mercedes                                             27f4d2
# 2483         Mercedes                                             27f4d2
# 2484      Kick Sauber  5200000000000000190003903645130092385429788960...
# 2485          McLaren                                             ff8000
#
#      first_name   last_name  \
# 0           Max  Verstappen
# 1         Logan    Sargeant
# 2         Lando      Norris
# 3        Pierre       Gasly
# 4        Sergio       Perez
# ...         ...         ...
# 2481     Oliver     Bearman
# 2482      Lewis    Hamilton
# 2483     George     Russell
# 2484   Valtteri      Bottas
# 2485      Oscar     Piastri
#
#                                            headshot_url country_code  \
# 0     https://www.formula1.com/content/dam/fom-websi...          NED
# 1     https://www.formula1.com/content/dam/fom-websi...          USA
# 2     https://www.formula1.com/content/dam/fom-websi...          GBR
# 3     https://www.formula1.com/content/dam/fom-websi...          FRA
# 4     https://www.formula1.com/content/dam/fom-websi...          MEX
# ...                                                 ...          ...
# 2481                                               None          GBR
# 2482  https://media.formula1.com/d_driver_fallback_i...          GBR
# 2483  https://media.formula1.com/d_driver_fallback_i...          GBR
# 2484  https://media.formula1.com/d_driver_fallback_i...          FIN
# 2485  https://media.formula1.com/d_driver_fallback_i...          AUS
#
#       session_key  meeting_key
# 0            7763         1140
# 1            7763         1140
# 2            7763         1140
# 3            7763         1140
# 4            7763         1140
# ...           ...          ...
# 2481         9480         1230
# 2482         9480         1230
# 2483         9480         1230
# 2484         9480         1230
# 2485         9480         1230
#
# [2486 rows x 12 columns]
